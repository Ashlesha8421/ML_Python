# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ###  Univariate , Bivariate and Multivariate Analysis On Iris Data-sets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import datasets
from sklearn import svm
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('whitegrid')

# system version 
print(np.__version__)
print(pd.__version__)
import sys
print(sys.version)
import sklearn
print(sklearn.__version__)
# Out:
# 1.19.2
# 1.1.3
# 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# 0.24.2

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ####  Univariate Analysis

# %%
df_setosa=df.loc[df['species']=='setosa']
df_virginica=df.loc[df['species']=='virginica']
df_versicolor = df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel('petal length')
plt.show()

# %% [markdown]
# #### Bivariate Analysis

# %%
## Take two features

# %%
sns.FacetGrid(df,hue="species",size=7).map(plt.scatter,"sepal_length","sepal_width").add_legend();
# Out:
# C:\Users\91830\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="species",size=7).map(plt.scatter,"petal_length","sepal_width").add_legend();
# Out:
# C:\Users\91830\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Multivariate Analysis

# %%
## Pair-plot
## More than 2 features

# %%
sns.pairplot(df,hue="species",size=3)
# Out:
# C:\Users\91830\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
